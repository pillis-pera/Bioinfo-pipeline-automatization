# %% [markdown]
# Generate counts matrix from each samples counts vector.

# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import datetime
import numpy as np

# %%
directory = Path("Counts/")


for i in directory.iterdir():
    df = pd.read_csv(i)
    print(df)
# Out:
#             Reference  Length  Mapped  Unmapped
# 0       hsa-let-7a-5p      22       1         0
# 1       hsa-let-7a-3p      21       0         0
# 2     hsa-let-7a-2-3p      22       0         0
# 3       hsa-let-7b-5p      22       5         0
# 4       hsa-let-7b-3p      22       0         0
# ...               ...     ...     ...       ...
# 2652    hsa-miR-12132      22       0         0
# 2653    hsa-miR-12133      22       0         0
# 2654    hsa-miR-12135      18       0         0
# 2655    hsa-miR-12136      18       0         0
# 2656                *       0       0         0
#
# [2657 rows x 4 columns]
#             Reference  Length  Mapped  Unmapped
# 0       hsa-let-7a-5p      22       2         0
# 1       hsa-let-7a-3p      21       0         0
# 2     hsa-let-7a-2-3p      22       0         0
# 3       hsa-let-7b-5p      22       7         0
# 4       hsa-let-7b-3p      22       0         0
# ...               ...     ...     ...       ...
# ...
