# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import datetime
import numpy as np

# %% [markdown]
# Generate counts matrix from each samples counts vector.

# %%
directory_samples = Path("Counts/")

samples = {}
for file in directory_samples.iterdir():
    df = pd.read_csv(file, usecols=["Reference","Mapped"])
    sample = file.stem
    samples[sample] = df.set_index("Reference")["Mapped"]
matrix = pd.concat(samples,axis=1)
matrix.index.name = "miRNA"
matrix.to_csv("counts_matrix.csv")
# Out:
#                  subset_sample_03  subset_sample_02  subset_sample_04
# miRNA
# hsa-let-7a-5p                   1                 2                 2
# hsa-let-7a-3p                   0                 0                 0
# hsa-let-7a-2-3p                 0                 0                 0
# hsa-let-7b-5p                   5                 7                 6
# hsa-let-7b-3p                   0                 0                 0
# ...                           ...               ...               ...
# hsa-miR-12132                   0                 0                 0
# hsa-miR-12133                   0                 0                 0
# hsa-miR-12135                   0                 0                 0
# hsa-miR-12136                   0                 0                 0
# *                               0                 0                 0
#
# [2657 rows x 3 columns]
